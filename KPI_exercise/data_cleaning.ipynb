# %%
import pandas as pd
from datetime import date
from dateutil.relativedelta import relativedelta

# %%
df1 = pd.read_csv('/Users/yairmartinez/Documents/GitHub/Data_analysis_exercises/DB/Datos/application_record.csv')
df2 = pd.read_csv('/Users/yairmartinez/Documents/GitHub/Data_analysis_exercises/DB/Datos/credit_record.csv')

# %%
df1.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
df2.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %%
# Pruebas

hoy=date.today()
mes_balance = hoy + relativedelta(months=-1)
print( hoy, mes_balance )
# Out:
# 2022-06-03 2022-05-03

# %%
# Data Cleaning

### Data cleaning de df 2 a df3 con cambios en fechas para hacerlas comprensibles

df3 = df1.assign(DAYS_BIRTH= lambda x: round(   ( (df1['DAYS_BIRTH'] *-1))/365   , 2  )   ,

 DAYS_EMPLOYED=lambda x: round(  ( (df1['DAYS_EMPLOYED'] *-1)) / 365      , 2  )          )


df3.rename(columns = {'DAYS_BIRTH':'YEARS_BIRTH'}, inplace = True)
df3.rename(columns = {'DAYS_EMPLOYED':'YEARS_EMPLOYED'}, inplace = True)

# %%
df4 = df2

# %%
### Data cleaning de df 2 a df3 con cambios en fechas para hacerlas comprensibles

hoy=date.today()
lista_mes_balance = []
for x in df4['MONTHS_BALANCE']:
    mes_balance = hoy + relativedelta(months=x)
    lista_mes_balance.append(mes_balance)

df4['MONTHS_BALANCE'] = lista_mes_balance
    
# df4 = df2.assign(MONTHS_BALANCE=lambda x: x.MONTHS_BALANCE )

# %%
df3.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  YEARS_BIRTH  YEARS_EMPLOYED  \
# ...

# %%
df4.head()
# Out:
#         ID MONTHS_BALANCE STATUS
# 0  5001711     2022-06-03      X
# 1  5001711     2022-05-03      0
# 2  5001711     2022-04-03      0
# 3  5001711     2022-03-03      0
# 4  5001712     2022-06-03      C

# %%
df3.to_csv('/Users/yairmartinez/Documents/GitHub/Data_analysis_exercises/DB/Datos_modificados/df3.csv')
df4.to_csv('/Users/yairmartinez/Documents/GitHub/Data_analysis_exercises/DB/Datos_modificados/df4.csv')

# df.to_csv("AllDetails.csv", index=False)
