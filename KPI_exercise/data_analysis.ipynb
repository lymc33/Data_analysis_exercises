# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/yairmartinez/Documents/GitHub/Data_analysis_exercises/DB/Datos_modificados/dfAll.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0           0  5008804           M            Y               Y             0
# 1           1  5008804           M            Y               Y             0
# 2           2  5008804           M            Y               Y             0
# 3           3  5008804           M            Y               Y             0
# 4           4  5008804           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          427500.0          Working    Higher education     Civil marriage
# 1          427500.0          Working    Higher education     Civil marriage
# 2          427500.0          Working    Higher education     Civil marriage
# 3          427500.0          Working    Higher education     Civil marriage
# 4          427500.0          Working    Higher education     Civil marriage
#
# ...

# %%
df.sample(5)
# Out:
#         Unnamed: 0       ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 446627      446627  5090273           M            Y               Y
# 173988      173988  5037095           F            Y               Y
# 64505        64505  5022664           M            Y               Y
# 333629      333629  5062468           M            Y               Y
# 154040      154040  5035437           F            Y               Y
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL      NAME_INCOME_TYPE  \
# 446627             1          112500.0  Commercial associate
# 173988             0          126000.0               Working
# 64505              0          157500.0  Commercial associate
# 333629             0          180000.0               Working
# 154040             0          180000.0               Working
#
#                   NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  ... YEARS_BIRTH  \
# 446627  Secondary / secondary special               Married  ...       42.58
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0            ID   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  777715.000000  7.777150e+05  777715.000000      7.777150e+05
# mean   388857.000000  5.078743e+06       0.428082      1.885348e+05
# std    224507.126638  4.180442e+04       0.745755      1.016225e+05
# min         0.000000  5.008804e+06       0.000000      2.700000e+04
# 25%    194428.500000  5.044568e+06       0.000000      1.215000e+05
# 50%    388857.000000  5.069530e+06       0.000000      1.620000e+05
# 75%    583285.500000  5.115551e+06       1.000000      2.250000e+05
# max    777714.000000  5.150487e+06      19.000000      1.575000e+06
#
#          YEARS_BIRTH  YEARS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# count  777715.000000   777715.000000    777715.0    777715.000000
# mean       44.177938     -158.290514         1.0         0.231818
# std        11.244663      373.896791         0.0         0.421993
# min        20.520000    -1000.670000         1.0         0.000000
# ...

# %%
df['YEARS_EMPLOYED'].min(axis=None, skipna=None, level=None, numeric_only=None, **kwargs)
# Out:
# -1000.67

# %%
a= df(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/v1/3g8467xs4vvf3w4gs3sqq6qr0000gn/T/ipykernel_15949/725896668.py in <module>
# ----> 1 a= df(0)
#
# TypeError: 'DataFrame' object is not callable

# %%
df2.info()

# %%
df1.isna().sum()

# %%
print( df1.shape, df2.shape )

# %%
union = pd.merge(df2, df1, how='inner', on=['ID'])

# %%
union.shape

# %%
union.head(5)

# %%
union.tail()

# %%
union.isna().sum()
